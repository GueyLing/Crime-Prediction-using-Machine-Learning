# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("Crimes_-_2001_to_Present.csv")
data.head()
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE  0870
# 2  11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE  0810
# 3  10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE  0560
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2        THEFT                OVER $500            RESIDENCE   False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 4      ASSAULT                   SIMPLE            APARTMENT   False
#
#    Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# 0      True  ...  12.0            61.0       08B     1165074.0    1875917.0
# 1     False  ...  29.0            25.0        06     1138875.0    1904869.0
# 2      True  ...   8.0            44.0        06           NaN          NaN
# 3     False  ...  35.0            21.0        18     1152037.0    1920384.0
# 4      True  ...  28.0            25.0       08A     1141706.0    1900086.0
#
#    Year              Updated On   Latitude  Longitude  \
# 0  2015  02/10/2018 03:50:01 PM  41.815117 -87.670000
# 1  2015  02/10/2018 03:50:01 PM  41.895080 -87.765400
# 2  2018  04/06/2019 04:04:43 PM        NaN        NaN
# 3  2015  02/10/2018 03:50:01 PM  41.937406 -87.716650
# 4  2015  02/10/2018 03:50:01 PM  41.881903 -87.755121
#
#                         Location
# 0  (41.815117282, -87.669999562)
# 1  (41.895080471, -87.765400451)
# 2                            NaN
# 3  (41.937405765, -87.716649687)
# 4  (41.881903443, -87.755121152)
#
# [5 rows x 22 columns]

# %%
df = data.copy()

# %%
#delete duplicated rows
df.drop_duplicates(subset=['Case Number'], inplace=True)

# %%
irrelevant_features = ['ID', 'Case Number', 'Block','IUCR', 'Ward','District','Beat', 'Description', 'Location Description', 'Arrest', 'Domestic','FBI Code', 'X Coordinate', 'Y Coordinate', 'Updated On', 'Latitude', 'Longitude', 'Location' ]  # Replace with the actual names of the irrelevant features in your dataset
df = df.drop(columns=irrelevant_features, axis = 1)

# %%
#drop the nullvalues
df.dropna(inplace=True)

# %%
# Define the primary types to remove
types_to_remove = ["NON-CRIMINAL", "NON - CRIMINAL", "NON-CRIMINAL (SUBJECT SPECIFIED)"]

# Remove samples with the specified primary types
df = df[~df["Primary Type"].isin(types_to_remove)]

# %%
# Convert "Date" column to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y %I:%M:%S %p')

# Extract day and month
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month

# %%
df = df[(df['Date'].dt.year >= 2018) & (df['Date'].dt.year <= 2022)]

# %%
df = df[df['Community Area'] != 0]

# %%
# Group by Community Area, Day, Month, and Year, and apply count aggregation
df = df.groupby(['Community Area', 'Day', 'Month', 'Year']).agg({'Community Area': 'count'})

# Rename the count column
df = df.rename(columns={'Community Area': 'Crime_Count'})

# Reset the index to convert the group labels back to columns
df = df.reset_index()

# %%
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count
# 0                  1.0    1      1  2018           12
# 1                  1.0    1      1  2019           18
# 2                  1.0    1      1  2020           12
# 3                  1.0    1      1  2021           14
# 4                  1.0    1      1  2022           16
# ...                ...  ...    ...   ...          ...
# 133641            77.0   31     12  2018            3
# 133642            77.0   31     12  2019            8
# 133643            77.0   31     12  2020            7
# 133644            77.0   31     12  2021            6
# 133645            77.0   31     12  2022            9
#
# [133646 rows x 5 columns]

# %%
import calendar
community_areas = range(1, 78)  # Community areas from 1 to 77
years = range(2018, 2023)  # Years from 2018 to 2022

all_combinations = [(area, year) for area in community_areas for year in years]

# Convert date columns to a datetime column
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Group the DataFrame by Community Area and Year
grouped = df.groupby(['Community Area', 'Year'])

# Create a list to store missing rows
missing_rows = []

# Loop through all combinations and find missing dates
for area, year in all_combinations:
    if (area, year) in grouped.groups:
        dates_present = set(grouped.get_group((area, year))['Date'])
        dates_expected = set(pd.date_range(start=f'{year}-01-01', end=f'{year}-12-31'))
        missing_dates = dates_expected - dates_present

        for date in missing_dates:
            day, month = date.day, date.month
            missing_rows.append({
                'Community Area': area,
                'Day': day,
                'Month': month,
                'Year': year,
                'Crime_Count': 0
            })

# Create a DataFrame for missing rows
missing_df = pd.DataFrame(missing_rows)

# Combine missing_df with the original DataFrame
combined_df = pd.concat([df, missing_df], ignore_index=True)

# Sort the DataFrame by date
combined_df = combined_df.sort_values(by=["Year", "Month", "Day"]).reset_index(drop=True)

df = combined_df.copy()

# %%
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count       Date
# 0                  1.0    1      1  2018           12 2018-01-01
# 1                  2.0    1      1  2018           14 2018-01-01
# 2                  3.0    1      1  2018           18 2018-01-01
# 3                  4.0    1      1  2018           10 2018-01-01
# 4                  5.0    1      1  2018            6 2018-01-01
# ...                ...  ...    ...   ...          ...        ...
# 140597            76.0   31     12  2022            1 2022-12-31
# 140598            77.0   31     12  2022            9 2022-12-31
# 140599            12.0   31     12  2022            0        NaT
# 140600            17.0   31     12  2022            0        NaT
# 140601            47.0   31     12  2022            0        NaT
#
# [140602 rows x 6 columns]

# %%
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])
df['Day_of_week'] = df['Date'].dt.day_name()

# %%
# Function to determine if a day is a weekend or not
def is_weekend(day_of_week):
    return day_of_week in ['Saturday', 'Sunday']

# Apply the function and create a new column 'is_weekend'
df['is_weekend'] = df['Day_of_week'].apply(is_weekend)

# %%
#Mapping seasons from month of crime
season_map = {
    (3,4,5) : 'Spring',
    (6,7,8) : 'Summer',
    (9,10,11) : 'Fall',
    (12,1,2) : 'Winter'
}
season_mapping = {}
for keys, values in season_map.items():
    for key in keys:
        season_mapping[key] = values
df['season'] = df.Month.map(season_mapping)

# %%
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count       Date Day_of_week  \
# 0                  1.0    1      1  2018           12 2018-01-01      Monday
# 1                  2.0    1      1  2018           14 2018-01-01      Monday
# 2                  3.0    1      1  2018           18 2018-01-01      Monday
# 3                  4.0    1      1  2018           10 2018-01-01      Monday
# 4                  5.0    1      1  2018            6 2018-01-01      Monday
# ...                ...  ...    ...   ...          ...        ...         ...
# 140597            76.0   31     12  2022            1 2022-12-31    Saturday
# 140598            77.0   31     12  2022            9 2022-12-31    Saturday
# 140599            12.0   31     12  2022            0 2022-12-31    Saturday
# 140600            17.0   31     12  2022            0 2022-12-31    Saturday
# 140601            47.0   31     12  2022            0 2022-12-31    Saturday
#
#         is_weekend  season
# 0            False  Winter
# 1            False  Winter
# 2            False  Winter
# 3            False  Winter
# 4            False  Winter
# ...            ...     ...
# 140597        True  Winter
# 140598        True  Winter
# 140599        True  Winter
# 140600        True  Winter
# 140601        True  Winter
#
# [140602 rows x 9 columns]

# %%
# Count the occurrences of each unique value in 'Primary Type'
value_counts = df['Crime_Count'].value_counts()

print("Number of occurrences of each unique value in 'Crime Count':")
print(value_counts)
# Out:
# Number of occurrences of each unique value in 'Crime Count':
# 2     13285
# 3     12876
# 1     11715
# 4     11606
# 5     10085
#       ...
# 76        1
# 69        1
# 80        1
# 85        1
# 86        1
# Name: Crime_Count, Length: 94, dtype: int64

# %%
test_df=df.copy()

# %%
# restart here
df=test_df.copy()

# %%
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Sort the DataFrame by date
df.sort_values('Date', inplace=True)
#A2
# Create lag features for crime count from 5 and 364 days ago for each community area
df['Crime_Count_Lag364'] = df.groupby('Community Area')['Crime_Count'].shift(364)
df['Crime_Count_Lag5'] = df.groupby('Community Area')['Crime_Count'].shift(5)

# %%
#A3
# Convert day, month, and year columns to a datetime format
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Sort the data by date within each community area
df.sort_values(by=['Community Area', 'Date'], inplace=True)

# Define the rolling window size (e.g., 7 days)
window_size = 30

# Create a new DataFrame to store the rolling window results
rolling_window_data = pd.DataFrame()

# Iterate through each community area
for area in df['Community Area'].unique():
    area_data = df[df['Community Area'] == area]
    
    # Apply rolling window calculation
    area_data['Rolling_Crime_Count'] = area_data['Crime_Count'].rolling(window=window_size+5, min_periods=1).apply(lambda x: x[:-5].mean(), raw=True)
    
    rolling_window_data = pd.concat([rolling_window_data, area_data])

# Display the rolling window data
df = rolling_window_data.copy()

# %%
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count       Date Day_of_week  \
# 0                  1.0    1      1  2018           12 2018-01-01      Monday
# 77                 1.0    2      1  2018            4 2018-01-02     Tuesday
# 154                1.0    3      1  2018           12 2018-01-03   Wednesday
# 231                1.0    4      1  2018            4 2018-01-04    Thursday
# 308                1.0    5      1  2018            8 2018-01-05      Friday
# ...                ...  ...    ...   ...          ...        ...         ...
# 140289            77.0   27     12  2022            7 2022-12-27     Tuesday
# 140366            77.0   28     12  2022            7 2022-12-28   Wednesday
# 140445            77.0   29     12  2022           11 2022-12-29    Thursday
# 140523            77.0   30     12  2022           10 2022-12-30      Friday
# 140598            77.0   31     12  2022            9 2022-12-31    Saturday
#
#         is_weekend  season  Crime_Count_Lag364  Crime_Count_Lag5  \
# 0            False  Winter                 NaN               NaN
# 77           False  Winter                 NaN               NaN
# 154          False  Winter                 NaN               NaN
# 231          False  Winter                 NaN               NaN
# 308          False  Winter                 NaN               NaN
# ...            ...     ...                 ...               ...
# 140289       False  Winter                 6.0               8.0
# 140366       False  Winter                 3.0               2.0
# 140445       False  Winter                10.0               6.0
# 140523       False  Winter                 6.0               4.0
# 140598        True  Winter                 5.0               4.0
#
#         Rolling_Crime_Count
# 0                       NaN
# 77                      NaN
# 154                     NaN
# 231                     NaN
# 308                     NaN
# ...                     ...
# 140289             8.533333
# 140366             8.300000
# 140445             8.266667
# 140523             8.100000
# 140598             7.966667
#
# [140602 rows x 12 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count       Date Day_of_week  \
# 28028              1.0   31     12  2018           11 2018-12-31      Monday
# 28105              1.0    1      1  2019           18 2019-01-01     Tuesday
# 28182              1.0    2      1  2019            8 2019-01-02   Wednesday
# 28259              1.0    3      1  2019           11 2019-01-03    Thursday
# 28336              1.0    4      1  2019            8 2019-01-04      Friday
# ...                ...  ...    ...   ...          ...        ...         ...
# 140289            77.0   27     12  2022            7 2022-12-27     Tuesday
# 140366            77.0   28     12  2022            7 2022-12-28   Wednesday
# 140445            77.0   29     12  2022           11 2022-12-29    Thursday
# 140523            77.0   30     12  2022           10 2022-12-30      Friday
# 140598            77.0   31     12  2022            9 2022-12-31    Saturday
#
#         is_weekend  season  Crime_Count_Lag364  Crime_Count_Lag5  \
# 28028        False  Winter                12.0              12.0
# 28105        False  Winter                 4.0               6.0
# 28182        False  Winter                12.0               8.0
# 28259        False  Winter                 4.0               7.0
# 28336        False  Winter                 8.0              10.0
# ...            ...     ...                 ...               ...
# 140289       False  Winter                 6.0               8.0
# 140366       False  Winter                 3.0               2.0
# 140445       False  Winter                10.0               6.0
# 140523       False  Winter                 6.0               4.0
# 140598        True  Winter                 5.0               4.0
#
#         Rolling_Crime_Count
# 28028              9.866667
# 28105              9.700000
# 28182              9.566667
# 28259              9.333333
# 28336              9.466667
# ...                     ...
# 140289             8.533333
# 140366             8.300000
# 140445             8.266667
# 140523             8.100000
# 140598             7.966667
#
# [112574 rows x 12 columns]

# %%
import math
df["Rolling_Crime_Count"] = df["Rolling_Crime_Count"].apply(math.ceil)

# %%
df.dropna(inplace=True)
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count       Date Day_of_week  \
# 28028              1.0   31     12  2018           11 2018-12-31      Monday
# 28105              1.0    1      1  2019           18 2019-01-01     Tuesday
# 28182              1.0    2      1  2019            8 2019-01-02   Wednesday
# 28259              1.0    3      1  2019           11 2019-01-03    Thursday
# 28336              1.0    4      1  2019            8 2019-01-04      Friday
# ...                ...  ...    ...   ...          ...        ...         ...
# 140289            77.0   27     12  2022            7 2022-12-27     Tuesday
# 140366            77.0   28     12  2022            7 2022-12-28   Wednesday
# 140445            77.0   29     12  2022           11 2022-12-29    Thursday
# 140523            77.0   30     12  2022           10 2022-12-30      Friday
# 140598            77.0   31     12  2022            9 2022-12-31    Saturday
#
#         is_weekend  season  Crime_Count_Lag364  Crime_Count_Lag5  \
# 28028        False  Winter                12.0              12.0
# 28105        False  Winter                 4.0               6.0
# 28182        False  Winter                12.0               8.0
# 28259        False  Winter                 4.0               7.0
# 28336        False  Winter                 8.0              10.0
# ...            ...     ...                 ...               ...
# 140289       False  Winter                 6.0               8.0
# 140366       False  Winter                 3.0               2.0
# 140445       False  Winter                10.0               6.0
# 140523       False  Winter                 6.0               4.0
# 140598        True  Winter                 5.0               4.0
#
#         Rolling_Crime_Count
# 28028                    10
# 28105                    10
# 28182                    10
# 28259                    10
# 28336                    10
# ...                     ...
# 140289                    9
# 140366                    9
# 140445                    9
# 140523                    9
# 140598                    8
#
# [112574 rows x 12 columns]

# %%
# from https://fred.stlouisfed.org/series/CHIC917URN
data2 = pd.read_csv("CHIC917URN.csv")
data2.head()
# Out:
#          DATE  CHIC917URN
# 0  1990-01-01         6.9
# 1  1990-02-01         6.6
# 2  1990-03-01         6.3
# 3  1990-04-01         6.5
# 4  1990-05-01         6.1

# %%
# Convert 'DATE' column to datetime format for both DataFrames
df['Date'] = pd.to_datetime(df[['Year', 'Month']].assign(day=1))
data2['DATE'] = pd.to_datetime(data2['DATE'])

# Merge the two DataFrames on the 'Date' column
df = pd.merge(df, data2, left_on='Date', right_on='DATE', how='inner')

# Drop the redundant 'Date' and 'DATE' columns
df.drop(['Date', 'DATE'], axis=1, inplace=True)

# %%
df.rename(columns={'CHIC917URN': 'Unemployment_Rate'}, inplace=True)

# %%
import holidays
country_code = 'US'  
holiday_obj = holidays.CountryHoliday(country_code)

# Convert 'Month', 'Day', and 'Year' columns to datetime format for holiday checking
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Check if each date is a holiday and create a new column 'Is_Holiday'
df['Is_Holiday'] = df['Date'].apply(lambda x: x in holiday_obj)

# Drop the 'Date' column if you no longer need it
df.drop(['Date'], axis=1, inplace=True)

# %%
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count Day_of_week  is_weekend  \
# 0                  1.0   31     12  2018           11      Monday       False
# 1                  2.0   31     12  2018            5      Monday       False
# 2                  3.0   31     12  2018            4      Monday       False
# 3                  4.0   31     12  2018            4      Monday       False
# 4                  5.0   31     12  2018            4      Monday       False
# ...                ...  ...    ...   ...          ...         ...         ...
# 112569            77.0   27     12  2022            7     Tuesday       False
# 112570            77.0   28     12  2022            7   Wednesday       False
# 112571            77.0   29     12  2022           11    Thursday       False
# 112572            77.0   30     12  2022           10      Friday       False
# 112573            77.0   31     12  2022            9    Saturday        True
#
#         season  Crime_Count_Lag364  Crime_Count_Lag5  Rolling_Crime_Count  \
# 0       Winter                12.0              12.0                   10
# 1       Winter                14.0              10.0                   11
# 2       Winter                18.0               6.0                   11
# 3       Winter                10.0               4.0                    5
# 4       Winter                 6.0               2.0                    4
# ...        ...                 ...               ...                  ...
# 112569  Winter                 6.0               8.0                    9
# 112570  Winter                 3.0               2.0                    9
# 112571  Winter                10.0               6.0                    9
# 112572  Winter                 6.0               4.0                    9
# 112573  Winter                 5.0               4.0                    8
#
#         Unemployment_Rate  Is_Holiday
# 0                     4.0       False
# 1                     4.0       False
# 2                     4.0       False
# 3                     4.0       False
# 4                     4.0       False
# ...                   ...         ...
# 112569                4.1       False
# 112570                4.1       False
# 112571                4.1       False
# 112572                4.1       False
# 112573                4.1       False
#
# [112574 rows x 13 columns]

# %%
#create pandas data frame object
data3 = pd.read_csv("Beach_Weather_Stations_-_Automated_Sensors.csv")

# %%
data3.head()
# Out:
#                   Station Name   Measurement Timestamp  Air Temperature  \
# 0  63rd Street Weather Station  09/27/2018 10:00:00 AM            16.40
# 1  63rd Street Weather Station  09/27/2018 11:00:00 AM            17.10
# 2  63rd Street Weather Station  09/27/2018 01:00:00 PM            18.20
# 3       Foster Weather Station  09/27/2018 01:00:00 PM            17.89
# 4  63rd Street Weather Station  09/27/2018 03:00:00 PM            19.50
#
#    Wet Bulb Temperature  Humidity  Rain Intensity  Interval Rain  Total Rain  \
# 0                  12.2        61             0.0            0.0       260.3
# 1                  11.5        51             0.0            0.0       260.3
# 2                  12.4        51             0.0            0.0       260.3
# 3                   NaN        39             NaN            0.0         NaN
# 4                  13.0        47             0.0            0.0       260.3
#
#    Precipitation Type  Wind Direction  Wind Speed  Maximum Wind Speed  \
# 0                 0.0             231         2.5                 4.7
# 1                 0.0             244         3.6                 5.7
# 2                 0.0             248         3.1                 5.3
# 3                 NaN             249         1.4                 2.3
# 4                 0.0             249         3.1                 5.7
#
#    Barometric Pressure  Solar Radiation  Heading  Battery Life  \
# 0                996.3              484    356.0          11.9
# 1                995.4              468    356.0          11.9
# 2                994.8              377    355.0          11.9
# 3                993.6                0      NaN          15.1
# 4                992.9              461    355.0          11.9
#
#   Measurement Timestamp Label                        Measurement ID
# 0         09/27/2018 10:00 AM  63rdStreetWeatherStation201809271000
# 1         09/27/2018 11:00 AM  63rdStreetWeatherStation201809271100
# 2          09/27/2018 1:00 PM  63rdStreetWeatherStation201809271300
# 3          09/27/2018 1:00 PM      FosterWeatherStation201809271300
# 4          09/27/2018 3:00 PM  63rdStreetWeatherStation201809271500

# %%
columns_to_keep = ['Station Name', 'Humidity', 'Air Temperature', 'Measurement Timestamp']
data3 = data3[columns_to_keep]

# %%
# Convert 'Measurement Timestamp' to datetime format
data3['Measurement Timestamp'] = pd.to_datetime(data3['Measurement Timestamp'])

# Group by date and calculate the average humidity and air temperature per day
average_data = data3.groupby(data3['Measurement Timestamp'].dt.date).agg({'Humidity': 'mean', 'Air Temperature': 'mean'})

# Create a new DataFrame with the calculated average values
average_df = pd.DataFrame(average_data).reset_index()
average_df.rename(columns={'Measurement Timestamp': 'Date'}, inplace=True)
average_df
# Out:
#             Date   Humidity  Air Temperature
# 0     2015-04-25  86.000000         7.000000
# 1     2015-04-30  76.000000         6.100000
# 2     2015-05-22  56.937500         9.695000
# 3     2015-05-23  48.925926        15.784000
# 4     2015-05-24  65.902439        16.507368
# ...          ...        ...              ...
# 2660  2023-08-15  74.636364        20.187500
# 2661  2023-08-16  55.155556        22.890889
# 2662  2023-08-17  58.354167        22.049792
# 2663  2023-08-18  53.435897        20.595385
# 2664  2023-08-19  46.500000        20.890000
#
# [2665 rows x 3 columns]

# %%
average_df['Date'] = pd.to_datetime(average_df['Date'])
average_df = average_df.loc[(average_df['Date'].dt.year >= 2019) & (average_df['Date'].dt.year <= 2022)]
average_df.set_index('Date', inplace=True)

# Generate a complete date range from the minimum to the maximum date
complete_date_range = pd.date_range(start=average_df.index.min(), end=average_df.index.max(), freq='D')

# Reindex the DataFrame with the complete date range
average_df = average_df.reindex(complete_date_range)

# Reset the index for the DataFrame
average_df.reset_index(inplace=True)
average_df.rename(columns={'index': 'Date'}, inplace=True)

# Change the 'Date' column to datetime format
average_df['Date'] = pd.to_datetime(average_df['Date'])

# %%
average_df
# Out:
#            Date   Humidity  Air Temperature
# 0    2019-01-01  82.041667        -0.538125
# 1    2019-01-02  78.234043        -0.967447
# 2    2019-01-03  70.562500         0.733333
# 3    2019-01-04  62.645833         4.921042
# 4    2019-01-05  68.375000         6.444583
# ...         ...        ...              ...
# 1456 2022-12-27  65.916667        -6.739792
# 1457 2022-12-28  63.377778         3.200667
# 1458 2022-12-29  76.553191        11.638298
# 1459 2022-12-30  73.125000         7.201667
# 1460 2022-12-31  78.375000         0.755208
#
# [1461 rows x 3 columns]

# %%
average_df['Humidity'].fillna(method='ffill', inplace=True)
average_df['Air Temperature'].fillna(method='ffill', inplace=True)

# %%
rows_with_null = average_df[average_df['Air Temperature'].isnull()]

print(rows_with_null)
# Out:
# Empty DataFrame
# Columns: [Date, Humidity, Air Temperature]
# Index: []

# %%
average_df['Date'] = pd.to_datetime(average_df['Date'])

# Generate a complete date range from the minimum to the maximum date
complete_date_range = pd.date_range(start=average_df['Date'].min(), end=average_df['Date'].max(), freq='D')

# Identify missing dates by finding the set difference between the complete range and existing dates
missing_dates = list(set(complete_date_range) - set(average_df['Date']))

print("Missing dates:")
for missing_date in missing_dates:
    print(missing_date)
# Out:
# Missing dates:

# %%
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count Day_of_week  is_weekend  \
# 0                  1.0   31     12  2018           11      Monday       False
# 1                  2.0   31     12  2018            5      Monday       False
# 2                  3.0   31     12  2018            4      Monday       False
# 3                  4.0   31     12  2018            4      Monday       False
# 4                  5.0   31     12  2018            4      Monday       False
# ...                ...  ...    ...   ...          ...         ...         ...
# 112569            77.0   27     12  2022            7     Tuesday       False
# 112570            77.0   28     12  2022            7   Wednesday       False
# 112571            77.0   29     12  2022           11    Thursday       False
# 112572            77.0   30     12  2022           10      Friday       False
# 112573            77.0   31     12  2022            9    Saturday        True
#
#         season  Crime_Count_Lag364  Crime_Count_Lag5  Rolling_Crime_Count  \
# 0       Winter                12.0              12.0                   10
# 1       Winter                14.0              10.0                   11
# 2       Winter                18.0               6.0                   11
# 3       Winter                10.0               4.0                    5
# 4       Winter                 6.0               2.0                    4
# ...        ...                 ...               ...                  ...
# 112569  Winter                 6.0               8.0                    9
# 112570  Winter                 3.0               2.0                    9
# 112571  Winter                10.0               6.0                    9
# 112572  Winter                 6.0               4.0                    9
# 112573  Winter                 5.0               4.0                    8
#
#         Unemployment_Rate  Is_Holiday
# 0                     4.0       False
# 1                     4.0       False
# 2                     4.0       False
# 3                     4.0       False
# 4                     4.0       False
# ...                   ...         ...
# 112569                4.1       False
# 112570                4.1       False
# 112571                4.1       False
# 112572                4.1       False
# 112573                4.1       False
#
# [112574 rows x 13 columns]

# %%
average_df['Date'] = pd.to_datetime(average_df['Date'])

# Merge the DataFrames based on common columns
df = pd.merge(df, average_df, left_on=['Day', 'Month', 'Year'], right_on=[average_df['Date'].dt.day, average_df['Date'].dt.month, average_df['Date'].dt.year])

# Drop the duplicate 'Date' columns after merging
df.drop(columns=['Date'], inplace=True)
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count Day_of_week  is_weekend  \
# 0                  1.0    1      1  2019           18     Tuesday       False
# 1                  2.0    1      1  2019           10     Tuesday       False
# 2                  3.0    1      1  2019           18     Tuesday       False
# 3                  4.0    1      1  2019            5     Tuesday       False
# 4                  5.0    1      1  2019            6     Tuesday       False
# ...                ...  ...    ...   ...          ...         ...         ...
# 112492            73.0   31     12  2022           14    Saturday        True
# 112493            74.0   31     12  2022            2    Saturday        True
# 112494            75.0   31     12  2022            5    Saturday        True
# 112495            76.0   31     12  2022            1    Saturday        True
# 112496            77.0   31     12  2022            9    Saturday        True
#
#         season  Crime_Count_Lag364  Crime_Count_Lag5  Rolling_Crime_Count  \
# 0       Winter                 4.0               6.0                   10
# 1       Winter                11.0               9.0                   11
# 2       Winter                 6.0               8.0                   11
# 3       Winter                 9.0               3.0                    5
# 4       Winter                 4.0               3.0                    4
# ...        ...                 ...               ...                  ...
# 112492  Winter                 8.0               2.0                    9
# 112493  Winter                 3.0               2.0                    2
# 112494  Winter                 8.0               4.0                    6
# 112495  Winter                 2.0               5.0                    6
# 112496  Winter                 5.0               4.0                    8
#
#         Unemployment_Rate  Is_Holiday   Humidity  Air Temperature
# 0                     5.1        True  82.041667        -0.538125
# 1                     5.1        True  82.041667        -0.538125
# 2                     5.1        True  82.041667        -0.538125
# 3                     5.1        True  82.041667        -0.538125
# 4                     5.1        True  82.041667        -0.538125
# ...                   ...         ...        ...              ...
# 112492                4.1       False  78.375000         0.755208
# 112493                4.1       False  78.375000         0.755208
# 112494                4.1       False  78.375000         0.755208
# 112495                4.1       False  78.375000         0.755208
# 112496                4.1       False  78.375000         0.755208
#
# [112497 rows x 15 columns]

# %%
# Function to calculate day of the year
def day_of_year(month, day):
    days_in_month = [0, 31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    day = sum(days_in_month[:month]) + day
    return day

# Create a new column 'DayOfYear' using the day_of_year function
df['DayOfYear'] = df.apply(lambda row: day_of_year(row['Month'], row['Day']), axis=1)

# Convert 'DayOfYear' column to integers
df['DayOfYear'] = df['DayOfYear'].astype(int)

# %%
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count Day_of_week  is_weekend  \
# 0                  1.0    1      1  2019           18     Tuesday       False
# 1                  2.0    1      1  2019           10     Tuesday       False
# 2                  3.0    1      1  2019           18     Tuesday       False
# 3                  4.0    1      1  2019            5     Tuesday       False
# 4                  5.0    1      1  2019            6     Tuesday       False
# ...                ...  ...    ...   ...          ...         ...         ...
# 112492            73.0   31     12  2022           14    Saturday        True
# 112493            74.0   31     12  2022            2    Saturday        True
# 112494            75.0   31     12  2022            5    Saturday        True
# 112495            76.0   31     12  2022            1    Saturday        True
# 112496            77.0   31     12  2022            9    Saturday        True
#
#         season  Crime_Count_Lag364  Crime_Count_Lag5  Rolling_Crime_Count  \
# 0       Winter                 4.0               6.0                   10
# 1       Winter                11.0               9.0                   11
# 2       Winter                 6.0               8.0                   11
# 3       Winter                 9.0               3.0                    5
# 4       Winter                 4.0               3.0                    4
# ...        ...                 ...               ...                  ...
# 112492  Winter                 8.0               2.0                    9
# 112493  Winter                 3.0               2.0                    2
# 112494  Winter                 8.0               4.0                    6
# 112495  Winter                 2.0               5.0                    6
# 112496  Winter                 5.0               4.0                    8
#
#         Unemployment_Rate  Is_Holiday   Humidity  Air Temperature  DayOfYear
# 0                     5.1        True  82.041667        -0.538125          1
# 1                     5.1        True  82.041667        -0.538125          1
# 2                     5.1        True  82.041667        -0.538125          1
# 3                     5.1        True  82.041667        -0.538125          1
# 4                     5.1        True  82.041667        -0.538125          1
# ...                   ...         ...        ...              ...        ...
# 112492                4.1       False  78.375000         0.755208        366
# 112493                4.1       False  78.375000         0.755208        366
# 112494                4.1       False  78.375000         0.755208        366
# 112495                4.1       False  78.375000         0.755208        366
# 112496                4.1       False  78.375000         0.755208        366
#
# [112497 rows x 16 columns]

# %%
# Create a new column 'Date' with the date represented as a string (e.g., "YYYYMMDD")
df['Date'] = df['Year'].astype(str) + df['Month'].astype(str).str.zfill(2) + df['Day'].astype(str).str.zfill(2)

# Sort the DataFrame by the 'Date' column in ascending order
df_sorted = df.sort_values(by='Date', ascending=True)

# Drop the temporary 'Date' column if not needed
df_sorted.drop(columns='Date', inplace=True)

df=df_sorted.copy()

# %%
df
# Out:
#         Community Area  Day  Month  Year  Crime_Count Day_of_week  is_weekend  \
# 0                  1.0    1      1  2019           18     Tuesday       False
# 55                56.0    1      1  2019            7     Tuesday       False
# 54                55.0    1      1  2019            4     Tuesday       False
# 53                54.0    1      1  2019            4     Tuesday       False
# 52                53.0    1      1  2019           19     Tuesday       False
# ...                ...  ...    ...   ...          ...         ...         ...
# 112442            23.0   31     12  2022           19    Saturday        True
# 112441            22.0   31     12  2022           11    Saturday        True
# 112440            21.0   31     12  2022            6    Saturday        True
# 112447            28.0   31     12  2022           31    Saturday        True
# 112496            77.0   31     12  2022            9    Saturday        True
#
#         season  Crime_Count_Lag364  Crime_Count_Lag5  Rolling_Crime_Count  \
# 0       Winter                 4.0               6.0                   10
# 55      Winter                 2.0               5.0                    7
# 54      Winter                 0.0               1.0                    2
# 53      Winter                 4.0               1.0                    4
# 52      Winter                12.0               9.0                   10
# ...        ...                 ...               ...                  ...
# 112442  Winter                14.0               7.0                   17
# 112441  Winter                 9.0               7.0                   13
# 112440  Winter                 8.0               0.0                    7
# 112447  Winter                26.0               8.0                   27
# 112496  Winter                 5.0               4.0                    8
#
#         Unemployment_Rate  Is_Holiday   Humidity  Air Temperature  DayOfYear
# 0                     5.1        True  82.041667        -0.538125          1
# 55                    5.1        True  82.041667        -0.538125          1
# 54                    5.1        True  82.041667        -0.538125          1
# 53                    5.1        True  82.041667        -0.538125          1
# 52                    5.1        True  82.041667        -0.538125          1
# ...                   ...         ...        ...              ...        ...
# 112442                4.1       False  78.375000         0.755208        366
# 112441                4.1       False  78.375000         0.755208        366
# 112440                4.1       False  78.375000         0.755208        366
# 112447                4.1       False  78.375000         0.755208        366
# 112496                4.1       False  78.375000         0.755208        366
#
# [112497 rows x 16 columns]

# %%
irrelevant_features = ['Day', 'Month']  # Replace with the actual names of the irrelevant features in your dataset
df = df.drop(columns=irrelevant_features, axis = 1)

# %%
df['DayOfYear_cos'] = np.cos(2 * np.pi * df['DayOfYear']/366.0)

# %%
df['DayOfYear_sin'] = np.sin(2 * np.pi * df['DayOfYear']/366.0)

# %%
df
# Out:
#         Community Area  Year  Crime_Count Day_of_week  is_weekend  season  \
# 0                  1.0  2019           18     Tuesday       False  Winter
# 55                56.0  2019            7     Tuesday       False  Winter
# 54                55.0  2019            4     Tuesday       False  Winter
# 53                54.0  2019            4     Tuesday       False  Winter
# 52                53.0  2019           19     Tuesday       False  Winter
# ...                ...   ...          ...         ...         ...     ...
# 112442            23.0  2022           19    Saturday        True  Winter
# 112441            22.0  2022           11    Saturday        True  Winter
# 112440            21.0  2022            6    Saturday        True  Winter
# 112447            28.0  2022           31    Saturday        True  Winter
# 112496            77.0  2022            9    Saturday        True  Winter
#
#         Crime_Count_Lag364  Crime_Count_Lag5  Rolling_Crime_Count  \
# 0                      4.0               6.0                   10
# 55                     2.0               5.0                    7
# 54                     0.0               1.0                    2
# 53                     4.0               1.0                    4
# 52                    12.0               9.0                   10
# ...                    ...               ...                  ...
# 112442                14.0               7.0                   17
# 112441                 9.0               7.0                   13
# 112440                 8.0               0.0                    7
# 112447                26.0               8.0                   27
# 112496                 5.0               4.0                    8
#
#         Unemployment_Rate  Is_Holiday   Humidity  Air Temperature  DayOfYear  \
# 0                     5.1        True  82.041667        -0.538125          1
# 55                    5.1        True  82.041667        -0.538125          1
# 54                    5.1        True  82.041667        -0.538125          1
# 53                    5.1        True  82.041667        -0.538125          1
# 52                    5.1        True  82.041667        -0.538125          1
# ...                   ...         ...        ...              ...        ...
# 112442                4.1       False  78.375000         0.755208        366
# 112441                4.1       False  78.375000         0.755208        366
# 112440                4.1       False  78.375000         0.755208        366
# 112447                4.1       False  78.375000         0.755208        366
# 112496                4.1       False  78.375000         0.755208        366
#
#         DayOfYear_cos  DayOfYear_sin
# 0            0.999853   1.716633e-02
# 55           0.999853   1.716633e-02
# 54           0.999853   1.716633e-02
# 53           0.999853   1.716633e-02
# 52           0.999853   1.716633e-02
# ...               ...            ...
# 112442       1.000000  -2.449294e-16
# 112441       1.000000  -2.449294e-16
# 112440       1.000000  -2.449294e-16
# 112447       1.000000  -2.449294e-16
# 112496       1.000000  -2.449294e-16
#
# [112497 rows x 16 columns]

# %%
def binary_encoding(col_name):
    # Perform Binary Numerical Encoding
    category_to_binary = {}
    binary_repr = []

    for category in df[col_name]:
        if category not in category_to_binary:
            category_to_binary[category] = bin(len(category_to_binary))[2:].zfill(len(bin(len(category_to_binary))) - 2)
        binary_repr.append(category_to_binary[category])

    # Store binary representation in a single feature
    df[col_name] = binary_repr
    df[col_name] = df[col_name].astype(int)

# %%
binary_encoding('Community Area')

# %%
binary_encoding('season')

# %%
binary_encoding('is_weekend')

# %%
binary_encoding('Is_Holiday')

# %%
irrelevant_features = ['DayOfYear' ]  # Replace with the actual names of the irrelevant features in your dataset
df = df.drop(columns=irrelevant_features, axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
encoder = LabelEncoder()

# Fit the encoder on the days_of_week data
encoder.fit(df['Day_of_week'])

# Transform the data using the encoder
df['Day_of_week'] = encoder.transform(df['Day_of_week'])

# %%
df['Day_of_week_sin'] = np.sin(2 * np.pi * df['Day_of_week']/7.0)
df['Day_of_week_cos'] = np.cos(2 * np.pi * df['Day_of_week']/7.0)
irrelevant_features = ['Day_of_week']  # Replace with the actual names of the irrelevant features in your dataset
df = df.drop(columns=irrelevant_features, axis = 1)

# %%
X = df.drop('Crime_Count', axis=1).values
y = df['Crime_Count'].values

print(X.shape)
print(y.shape)
# Out:
# (112497, 15)
# (112497,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, shuffle=False)

# %%
X_train_df = pd.DataFrame(X_test, columns=['Community Area','Year','is_weekend','season','Crime_Count_Lag364','Crime_Count_Lag5','Rolling_Crime_Count','Unemployment_Rate','Is_Holiday','Humidity','Air Temperature',
                                           'DayOfYear_cos','DayOfYear_sin','Day_of_week_sin','Day_of_week_cos'
                                        ])
X_train_df
# Out:
#        Community Area    Year  is_weekend  season  Crime_Count_Lag364  \
# 0           1000101.0  2022.0         1.0    10.0                 8.0
# 1           1000110.0  2022.0         1.0    10.0                17.0
# 2           1000111.0  2022.0         1.0    10.0                40.0
# 3           1001000.0  2022.0         1.0    10.0                14.0
# 4           1001001.0  2022.0         1.0    10.0                20.0
# ...               ...     ...         ...     ...                 ...
# 11245       1001001.0  2022.0         1.0     0.0                14.0
# 11246       1001010.0  2022.0         1.0     0.0                 9.0
# 11247       1001011.0  2022.0         1.0     0.0                 8.0
# 11248       1001100.0  2022.0         1.0     0.0                26.0
# 11249         10100.0  2022.0         1.0     0.0                 5.0
#
#        Crime_Count_Lag5  Rolling_Crime_Count  Unemployment_Rate  Is_Holiday  \
# 0                  15.0                 10.0                5.0         1.0
# 1                  15.0                 13.0                5.0         1.0
# 2                  46.0                 35.0                5.0         1.0
# 3                  29.0                 22.0                5.0         1.0
# 4                  17.0                 16.0                5.0         1.0
# ...                 ...                  ...                ...         ...
# 11245               7.0                 17.0                4.1         1.0
# 11246               7.0                 13.0                4.1         1.0
# 11247               0.0                  7.0                4.1         1.0
# 11248               8.0                 27.0                4.1         1.0
# 11249               4.0                  8.0                4.1         1.0
#
#         Humidity  Air Temperature  DayOfYear_cos  DayOfYear_sin  \
# 0      82.642857        26.032429      -0.804962  -5.933268e-01
# 1      82.642857        26.032429      -0.804962  -5.933268e-01
# 2      82.642857        26.032429      -0.804962  -5.933268e-01
# 3      82.642857        26.032429      -0.804962  -5.933268e-01
# 4      82.642857        26.032429      -0.804962  -5.933268e-01
# ...          ...              ...            ...            ...
# 11245  78.375000         0.755208       1.000000  -2.449294e-16
# 11246  78.375000         0.755208       1.000000  -2.449294e-16
# 11247  78.375000         0.755208       1.000000  -2.449294e-16
# 11248  78.375000         0.755208       1.000000  -2.449294e-16
# 11249  78.375000         0.755208       1.000000  -2.449294e-16
#
#        Day_of_week_sin  Day_of_week_cos
# 0             0.433884        -0.900969
# 1             0.433884        -0.900969
# 2             0.433884        -0.900969
# 3             0.433884        -0.900969
# 4             0.433884        -0.900969
# ...                ...              ...
# 11245         0.974928        -0.222521
# 11246         0.974928        -0.222521
# 11247         0.974928        -0.222521
# 11248         0.974928        -0.222521
# 11249         0.974928        -0.222521
#
# [11250 rows x 15 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both X_train and X_test
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.preprocessing import MinMaxScaler
# Create the MinMaxScaler object
scaler = MinMaxScaler()

# Fit the scaler on the training data and transform X_train
X_train_normalized = scaler.fit_transform(X_train)

# Transform X_test using the same scaler
X_test_normalized = scaler.transform(X_test)

# %%
pd.set_option('display.max_columns', None)  # Set this option to display all columns
df
# Out:
#         Community Area  Year  Crime_Count  is_weekend  season  \
# 0                    0  2019           18           0       0
# 55                   1  2019            7           0       0
# 54                  10  2019            4           0       0
# 53                  11  2019            4           0       0
# 52                 100  2019           19           0       0
# ...                ...   ...          ...         ...     ...
# 112442         1001001  2022           19           1       0
# 112441         1001010  2022           11           1       0
# 112440         1001011  2022            6           1       0
# 112447         1001100  2022           31           1       0
# 112496           10100  2022            9           1       0
#
#         Crime_Count_Lag364  Crime_Count_Lag5  Rolling_Crime_Count  \
# 0                      4.0               6.0                   10
# 55                     2.0               5.0                    7
# 54                     0.0               1.0                    2
# 53                     4.0               1.0                    4
# 52                    12.0               9.0                   10
# ...                    ...               ...                  ...
# 112442                14.0               7.0                   17
# 112441                 9.0               7.0                   13
# 112440                 8.0               0.0                    7
# 112447                26.0               8.0                   27
# 112496                 5.0               4.0                    8
#
#         Unemployment_Rate  Is_Holiday   Humidity  Air Temperature  \
# 0                     5.1           0  82.041667        -0.538125
# 55                    5.1           0  82.041667        -0.538125
# 54                    5.1           0  82.041667        -0.538125
# 53                    5.1           0  82.041667        -0.538125
# 52                    5.1           0  82.041667        -0.538125
# ...                   ...         ...        ...              ...
# 112442                4.1           1  78.375000         0.755208
# 112441                4.1           1  78.375000         0.755208
# 112440                4.1           1  78.375000         0.755208
# 112447                4.1           1  78.375000         0.755208
# 112496                4.1           1  78.375000         0.755208
#
#         DayOfYear_cos  DayOfYear_sin  Day_of_week_sin  Day_of_week_cos
# 0            0.999853   1.716633e-02        -0.974928        -0.222521
# 55           0.999853   1.716633e-02        -0.974928        -0.222521
# 54           0.999853   1.716633e-02        -0.974928        -0.222521
# 53           0.999853   1.716633e-02        -0.974928        -0.222521
# 52           0.999853   1.716633e-02        -0.974928        -0.222521
# ...               ...            ...              ...              ...
# 112442       1.000000  -2.449294e-16         0.974928        -0.222521
# 112441       1.000000  -2.449294e-16         0.974928        -0.222521
# 112440       1.000000  -2.449294e-16         0.974928        -0.222521
# 112447       1.000000  -2.449294e-16         0.974928        -0.222521
# 112496       1.000000  -2.449294e-16         0.974928        -0.222521
#
# [112497 rows x 16 columns]

# %% [markdown]
# # Machine Learning Algorithms

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

model = lgb.LGBMRegressor(random_state=42)
model.fit(X_train_scaled, y_train)
y_train_pred = model.predict(X_train_scaled)
train_r2 = r2_score(y_train, y_train_pred)

y_pred = model.predict(X_test_scaled)
# Calculate coefficient of determination (R^2)
r2 = r2_score(y_test, y_pred)

# Print the predicted values and R^2 score
print('Train R2 Score:', train_r2)
print('Test R2 Score:', r2)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001215 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1333
# [LightGBM] [Info] Number of data points in the train set: 101247, number of used features: 15
# [LightGBM] [Info] Start training from score 8.068298
# Train R2 Score: 0.8204473811692998
# Test R2 Score: 0.8068079566917834

# %%
from itertools import product
# Define a dictionary of hyperparameter values to try
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'num_leaves': [20, 30, 40],
    'min_child_samples': [10, 20, 30],
    'reg_alpha': [0.0, 0.1, 0.5],
    'reg_lambda': [0.0, 0.1, 0.5]
}

# Get all possible combinations of hyperparameter values
param_combinations = list(product(*param_grid.values()))

# Initialize variables to track the best result
best_params = None
best_test_r2 = -np.inf  # Initialize with negative infinity

# Initialize a dictionary to store individual R-squared scores
individual_r2_scores = {}

# Loop over each hyperparameter combination
for params in param_combinations:
    # Create a LightGBM regression model
    model = lgb.LGBMRegressor(random_state=42, force_row_wise=True)

    # Set the model's hyperparameters
    param_dict = dict(zip(param_grid.keys(), params))
    model.set_params(**param_dict)

    model.set_params(verbose=-1)
    # Fit the model on the training data
    model.fit(X_train_scaled, y_train)

    # Predict on the test set
    y_pred_test = model.predict(X_test_scaled)

    # Calculate the R-squared score on the test set
    test_r2 = r2_score(y_test, y_pred_test)

    # Store the individual R-squared score for this combination
    individual_r2_scores[str(param_dict)] = test_r2

    # Check if this is the best result so far
    if test_r2 > best_test_r2:
        best_test_r2 = test_r2
        best_params = param_dict

# Print individual R-squared scores for each combination
for params, r2 in individual_r2_scores.items():
    print(f"Hyperparameters: {params}, Test R-squared: {r2}")

# Print the best hyperparameters and corresponding R-squared score
print("\nBest Hyperparameters:", best_params)
print(f"Best Test R-squared: ",best_test_r2)
#1.47pm
# Out:
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.6891457382570843
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.6890760542797494
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.6890342005106942
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.6891023392994586
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.6891672935928632
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.6888937108962272
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.6892506329203852
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.6892114275924213
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.6888567853900571
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.6894988635945762
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.6892827124828702
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.6891585549460766
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.6894969591440012
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.6892809308165039
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.6887018404501695
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.6895145878659561
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.6892967110187089
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.6890740539805063
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.6905909704781356
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.6906220936162587
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.6904176798696148
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.6905889028934609
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.690405552529276
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.6892635077665219
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.6905278768219704
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.6905801508009215
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.68928654558965
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.6913358073708586
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.6912729361241703
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.6907038221864297
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.6912752488613121
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.6914256207699743
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.6909542749483388
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.6912656090243813
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.6910584706336924
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.6907566973001811
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.6904558421545777
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.690576419875849
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.6902742964108177
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.6906502146116394
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.6905454766799421
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.6904598682424943
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.690541802428789
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.6907869456220612
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.6902399910387369
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.6921743802948465
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.6919239517916785
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.6917953638863334
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.6920186517897265
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.6919382073604365
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.6918333136204007
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.6920558352079955
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.6921469182002364
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.6910217502464068
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.6905671770808612
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.6904634810362797
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.6908342012679827
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.6903425542039209
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.6905068268871941
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.690677545685902
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.6903663519826946
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.69045826481694
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.6908507761750353
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.6914807399813723
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.6914714377557496
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.6909727680750082
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.6914377968024885
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.6911712724803456
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.6910473278782698
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.6915267009777069
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.6912684419671055
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.6909929888532578
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.6937675842508173
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.6941024078348723
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.6931283659711678
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.6936957991817081
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.6934133338363485
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.6939628090977301
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.6935328939758305
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.694225316538244
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.6931107681570838
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8055183456254311
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8048875970929347
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8044001819078006
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8058098674892172
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8053807663456841
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8038490936233857
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.804504729184972
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8049443959977371
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8057099333307622
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.804329009812626
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8042757669003251
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8054798899622927
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8050113084848668
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8051866628264976
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8049124623162929
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.805368191239137
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8043871585667459
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8055538855600963
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8056894642610057
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8042094614096382
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8059753321068419
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8055066606134328
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8046986908558473
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8050793008372904
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8044126272353164
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8053662955223984
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8030718942956525
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8063110084071013
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8065170602409706
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8069072747770787
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8063360943962221
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8070444410007488
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8073736026835614
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8066910915440846
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8068544192091689
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8062563916263035
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8058215429974556
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8065412893231118
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8065733007221485
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.805618768917617
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8071285373248066
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.806604346332166
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8064146861044833
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8059414601100424
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8066195859362977
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8056064997707411
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8076001186032199
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.806088326054529
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8063429866124721
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8065687182731827
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8057656508541842
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8074141166756412
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8068349419354119
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8063396448262523
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8063798730445393
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8068397812624573
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8066902309257982
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8068492300074273
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8076573625610912
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8063939426123485
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8069319439438118
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.807147327929387
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8058650703196155
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8063346323044631
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8072343139852273
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8071568974308097
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8058966687626183
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8070896896827752
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8060432805300124
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8066381767703537
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8068391323052777
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8078720322997748
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.806842568485979
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.806850339823864
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8057561467478851
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8062284043806885
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8071040469570862
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.806995143183457
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8064534593336941
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8072462786222935
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8070377096254499
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8064612121780694
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8059000996485588
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8059343405000557
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8039251813158577
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8062626438310091
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8052619247183727
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8035613147125323
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.80594481031077
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8056452319009206
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8052401291612054
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8025920098307573
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8033885028686465
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.805949194348496
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8026675644272617
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8062675022200083
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8060924387707917
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8031955051753127
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8036985704782239
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.7986198384584258
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.800698979341126
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8048533551868154
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8001571205832494
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8015424819666336
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8038486374675303
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8010686205468291
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8017999045212759
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.804527669566831
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8052795722525415
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8056614555081234
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8048144480057019
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8052860634821456
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8062837649811321
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8036702576083606
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.805191476040956
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8060477827838124
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8063001814194243
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8054130267145625
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8067787980169383
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8048417302609108
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8050997075840034
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8059397498714399
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8050977183609889
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8048851283896243
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8043217795261886
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8055629475448215
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8038087459782889
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8031298894909842
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8032821421831289
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8068712294429554
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8024250065611237
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.80530986895087
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8046080703466418
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8038926589052683
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8060467533235611
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8057724339316072
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8054475910976854
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8075508305676283
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.806154542015934
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8059976787024938
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8050162013745457
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8036244890300344
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8060205660451936
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8063236482038858
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8054257719702437
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8053306395296985
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8052570899076718
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8037236075962177
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8052910626743569
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8050668259177883
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8053317236159021
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8036266052038241
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8060994867172729
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.803568455314802
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8018473916912687
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8059986583322307
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8042325723906416
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8062841744477319
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8045688648536151
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.804008513559559
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8043095266861742
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8023482193489657
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.7814804534762858
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.7814141764806259
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.7815442048002111
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.7814220015577321
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.7815506144753626
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.7815232341237008
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.7815955422298976
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.7815377423859666
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.7814772397040927
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.782290573669294
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.7820477636253452
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.7818743463188864
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.7822235259809136
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.7819863947964427
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.7820023772790812
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.7823037306164393
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.7821841519740131
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.7821202607029998
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.783891764592928
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.7834658647938366
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.782789068884697
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.7831526013710857
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.7837676689072829
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.7836225381776257
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.7832091043478471
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.7828532750393316
# Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.01, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.7833466482770237
# ...
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8049021203203982
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.806039438190153
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8056088772184895
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8044717042123162
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8054434289789538
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8047475617137574
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8059945402736908
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.1, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8060828514397332
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8032316366877469
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8016499966594525
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8033253760814518
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8020022716078612
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8037679618292068
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8044969132494332
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8011189340619302
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.803685216117404
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8026089022093319
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8035968783065606
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8020071941406818
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8029048735735748
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.804161454008818
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.7993055955010724
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8006783075109002
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.803569741350503
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8017957532582558
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8005594435728919
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.7981308671035823
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.7969002406002528
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8025562139414096
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.7991491077508561
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8014656681227137
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8032295914374044
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.7996903877591617
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8002991106241941
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 20, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8040632154701599
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8024147745244053
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8034024661514853
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8025231422383752
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.7998826597559496
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.7967634070484628
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.7998369462577802
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8033357780929586
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8036473572983894
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8020500049205346
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8001911300418971
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8026082484320998
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.801129630247512
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8013401275527249
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.799648155155179
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8013888097442043
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8003134315071674
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8006399493029647
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8005241178464124
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.8004216712838008
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8001500988988826
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.7994828565184715
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8038016392775195
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.798768949412714
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.8028328974498601
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8017491689609793
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8013592952291657
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 30, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8023240695756081
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.7997132669433263
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.8027905256604342
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.804913256492669
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.801024280058678
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8010164707209131
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.7987765293385972
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.7968885103084145
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8021706222266775
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 10, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8029021770456648
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.7992199765786259
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.7995870755350769
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.799329116326307
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.7990382057325554
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.800690769533152
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.7986656901119883
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.8003841531620122
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.7979537069863368
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 20, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.8002594486721981
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.0}, Test R-squared: 0.7987577435279278
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.1}, Test R-squared: 0.7964525763587296
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.0, 'reg_lambda': 0.5}, Test R-squared: 0.8006202581642364
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.0}, Test R-squared: 0.8008118748798563
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.1}, Test R-squared: 0.8019429268096852
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.5}, Test R-squared: 0.7993153534326235
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.0}, Test R-squared: 0.7986641970660621
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.1}, Test R-squared: 0.8011659006104819
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'num_leaves': 40, 'min_child_samples': 30, 'reg_alpha': 0.5, 'reg_lambda': 0.5}, Test R-squared: 0.798313875360468
#
# Best Hyperparameters: {'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 30, 'min_child_samples': 10, 'reg_alpha': 0.1, 'reg_lambda': 0.5}
# Best Test R-squared:  0.8085611134247497

# %%
# Define the hyperparameters
params = {
    'n_estimators': 200,
    'learning_rate': 0.1,
    'num_leaves': 30,
    'min_child_samples': 10,
    'reg_alpha': 0.1,
    'reg_lambda': 0.5,
    'random_state': 42  # Set a random state for reproducibility
}

# Create a LightGBM regression model with the specified hyperparameters
model = lgb.LGBMRegressor(**params)

# Fit the model on the training data
model.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred_test = model.predict(X_test_scaled)

# Calculate the R-squared score on the test set
test_r2 = r2_score(y_test, y_pred_test)

# Print the R-squared score for this model
print(f"Test R-squared: ",test_r2)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001229 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1333
# [LightGBM] [Info] Number of data points in the train set: 101247, number of used features: 15
# [LightGBM] [Info] Start training from score 8.068298
# Test R-squared:  0.8085611134247497

# %%
from sklearn.metrics import r2_score
import xgboost as xgb

model = xgb.XGBRegressor(random_state=42)
model.fit(X_train_scaled, y_train)
y_train_pred = model.predict(X_train_scaled)
train_r2 = r2_score(y_train, y_train_pred)

y_pred = model.predict(X_test_scaled)
# Calculate coefficient of determination (R^2)
r2 = r2_score(y_test, y_pred)

# Print the predicted values and R^2 score
print('Train R2 Score:', train_r2)
print('Test R2 Score:', r2)
# Out:
# Train R2 Score: 0.8562910082332412
# Test R2 Score: 0.8011603835187074

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_child_weight': [2, 3, 4],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'gamma': [1, 2, 3],
}

# Create a list of all hyperparameter combinations
param_combinations = list(product(*param_grid.values()))

# Initialize variables to track the best result
best_params = None
best_test_r2 = -float('inf')

# Iterate through each hyperparameter combination
for params in param_combinations:
    hyperparameters = dict(zip(param_grid.keys(), params))

    # Create an XGBoost model with the current hyperparameters
    xgb_model = xgb.XGBRegressor(**hyperparameters, random_state=42)

    # Train the model on the training data
    xgb_model.fit(X_train_scaled, y_train)

    # Predict on the test set
    y_pred_test = xgb_model.predict(X_test_scaled)

    # Calculate the R-squared score on the test set
    test_r2 = r2_score(y_test, y_pred_test)

    # Print the hyperparameters and the corresponding R-squared score
    print("Hyperparameters:", hyperparameters)
    print(f"Test R-squared:",test_r2)
    print("-" * 50)

    # Check if this is the best result so far
    if test_r2 > best_test_r2:
        best_test_r2 = test_r2
        best_params = hyperparameters

# Print the best hyperparameters and corresponding best test R-squared score
print("Best Hyperparameters:", best_params)
print(f"Best Test R-squared:", best_test_r2)
# Out:
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8011165237884211
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8011165237884211
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8011165237884211
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8010822226164741
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8010822226164741
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8010822226164741
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.7999591101135952
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.7999591101135952
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.7999591099164227
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8012183940840568
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8012183940840568
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8012183940840568
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8006480076283511
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8006480076283511
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8006480076283511
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8002542400904646
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8002542430102704
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8002542430102704
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8008025326803944
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8008025252295385
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8008025252295385
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8010155320949485
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8010155320949485
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8010155320949485
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8007244068700083
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8007244068700083
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8008627656011942
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8005246724872558
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8005246724872558
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8005246724872558
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.800847353815199
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.800847353815199
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.800847353815199
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8001665971752323
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8001665971752323
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8001665971752323
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8012103726164788
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8012103726164788
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8012103726164788
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8009655468741118
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8009655468741118
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8009655468741118
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.800624482900037
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8005668501599417
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8005668501599417
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.801376498584162
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.801376498584162
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.801376498584162
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8016503293315859
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8016503590060808
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8016502113763792
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8002697328137041
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.800216928197539
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.800216928197539
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8009224763286747
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8009224763286747
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8009224763286747
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8017097826973609
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8017097826973609
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8017097826973609
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.7996040480756805
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.7996040480756805
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.7996040480756805
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.801250685885479
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.801250685885479
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.801250685885479
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8009259077466243
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8009259077466243
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8009259077466243
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.800854514647089
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.800854514647089
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.800854514647089
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8007595801542164
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8007595801542164
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8007529872740258
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8014355687351508
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8014355687351508
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8014355687351508
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8001928184848023
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8001928184848023
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8001928184848023
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.802837652852456
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.802837652852456
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8028382217291402
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8042148185293703
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8042148091302527
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8042148091302527
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.803160070894505
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8031602043718273
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8032606450917392
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.804204297662265
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8042042781969365
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8042037024048124
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8034446521403961
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8034412648652864
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.80344282187564
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8041202903262962
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8041202942558175
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8041202942558175
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8037203977217602
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8037203947919789
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8043310069757553
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8041778334551322
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8038967200807567
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8040349742287533
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8027396071183328
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8027396071183328
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8027278819870172
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8037014578982821
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8037014578982821
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8037014578982821
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8032358736620664
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8032359141944612
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8032359141944612
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8031792285940416
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8031792166280419
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8031792308433826
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.803774046865859
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8041231798730895
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.803855478851715
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8032234921889513
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8032234921889513
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8032238825657428
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8035538635357211
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8035538635357211
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8035538635357211
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8033459475901803
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8033459612138478
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8033459612138478
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8036817416431706
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8036817295581166
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.803743188966102
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8027306031321284
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8027305511270613
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8027305512367214
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8033979890719164
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8033979890719164
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8033979890719164
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8039628887674597
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8039628887674597
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8039628887674597
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8033091757927691
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8033091757927691
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8033091757927691
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8046143802603283
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8046143802603283
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8046143802603283
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8038588427605291
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8038586601680643
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8038586601680643
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8043760084014511
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8042562013315797
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8042562174179503
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8036466720418971
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8036466650995084
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8036466844371285
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8042828729077242
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8042828653986484
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8042827899426974
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8032970993698549
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8032970993698549
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8035020048754404
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8047381288412444
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8046128727090074
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8043570527540804
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8071487478050889
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8071489170953672
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8071488283910497
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8054976275529879
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8053546324749938
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8053546353930413
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8058335484040844
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8060395898215452
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8057382607141105
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.805909562030004
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8057712334076168
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8061816153295693
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.805276629744564
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8052041551224796
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8052041546771114
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8044166406931523
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.804256723253949
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8045397216629098
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8055480900314255
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8054878351676272
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8057641875408483
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8049656201197679
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8051087671694082
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8051086348163167
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8061415888214575
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8061182931561836
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8061183955718012
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8055255232275385
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8055256999780998
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.80550574120597
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8050920509683004
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8057473196812572
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.805220648947332
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8051504356201601
# --------------------------------------------------
# ...
# Test R-squared: 0.8009537433342437
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.798207510071394
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.7976808242313305
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8038745056790932
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.802870389240278
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8030855781334386
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8000931448377662
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8023582915957006
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8038456267798844
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8013130476130844
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8011506432471104
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8014813977743884
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8008949441426381
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8017246510487159
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.7991184918088108
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.7992262273201459
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8015722141295343
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.7985907469244198
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.7991286187873636
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.7991665728671729
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.7995594800161492
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.7993620364971306
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8000340671710569
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.7996326092217683
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8004953237105068
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.7970430121592251
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8014911743537616
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8007774305449603
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.7987460821297823
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.7989712225490437
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8024217862009736
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8016413958670505
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.80263217479734
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.803365509610412
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8026224905076121
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8017739279580779
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8032922920873206
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8013715735838572
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8024736297177738
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.798876887847692
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.7996390813606991
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.799663151073032
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8005349089902626
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8029536164749583
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8013836350459957
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.7997808321628933
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.7984685526298745
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.7982294548482254
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.7984377099255632
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.7969346201540546
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.8003688216689352
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8023014123377353
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8019354006410762
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.7987915835117712
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8013746785306886
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8003302032351498
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8012125510441247
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 1}
# Test R-squared: 0.8022458822395897
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 2}
# Test R-squared: 0.8029007675609137
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.8, 'gamma': 3}
# Test R-squared: 0.803541123451717
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1}
# Test R-squared: 0.8066065974112526
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 2}
# Test R-squared: 0.8029156300177869
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 3}
# Test R-squared: 0.8053701863534711
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 1}
# Test R-squared: 0.8017473301343093
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 2}
# Test R-squared: 0.8031002257186137
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 3}
# Test R-squared: 0.8023871949775208
# --------------------------------------------------
# Best Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'gamma': 3}
# Best Test R-squared: 0.8087870426216732

# %%
from sklearn.metrics import r2_score
import xgboost as xgb 

hyperparameters = {
    'n_estimators': 300,
    'learning_rate': 0.1,
    'max_depth': 5,
    'min_child_weight': 4,
    'subsample': 0.9,
    'colsample_bytree': 0.9,
    'gamma': 3,
    'random_state': 42  # Set a random state fov r reproducibility
}

model = xgb.XGBRegressor(**hyperparameters)
model.fit(X_train_scaled, y_train)
y_train_pred = model.predict(X_train_scaled)
train_r2 = r2_score(y_train, y_train_pred)

y_pred = model.predict(X_test_scaled)
# Calculate coefficient of determination (R^2)
r2 = r2_score(y_test, y_pred)

# Print the predicted values and R^2 score
print('Train R2 Score:', train_r2)
print('Test R2 Score:', r2)
# Out:
# Train R2 Score: 0.8333586061981371
# Test R2 Score: 0.8087870426216732

# %%
from catboost import CatBoostRegressor

# Create and train a CatBoostRegressor
model = CatBoostRegressor(random_state=42)
model.fit(X_train_scaled, y_train, verbose=100)
y_train_pred = model.predict(X_train_scaled)
train_r2 = r2_score(y_train, y_train_pred)

# Predict on the test set
y_pred = model.predict(X_test_scaled)

# Evaluate the model
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the predicted values and R^2 score
print('Train R2 Score:', train_r2)
print('Test R2 Score:', r2)
# Out:
# Learning rate set to 0.084924
# 0:	learn: 7.3607141	total: 23.9ms	remaining: 23.9s
# 100:	learn: 3.4874777	total: 739ms	remaining: 6.58s
# 200:	learn: 3.3984048	total: 1.45s	remaining: 5.78s
# 300:	learn: 3.3397511	total: 2.16s	remaining: 5.02s
# 400:	learn: 3.2881418	total: 2.87s	remaining: 4.29s
# 500:	learn: 3.2375973	total: 3.56s	remaining: 3.55s
# 600:	learn: 3.1950423	total: 4.25s	remaining: 2.82s
# 700:	learn: 3.1573895	total: 4.94s	remaining: 2.11s
# 800:	learn: 3.1253837	total: 5.64s	remaining: 1.4s
# 900:	learn: 3.0981936	total: 6.33s	remaining: 695ms
# 999:	learn: 3.0756645	total: 7.01s	remaining: 0us
# Train R2 Score: 0.8462702034412113
# Test R2 Score: 0.8025052609703582

# %%
param_grid = {
    'iterations': [1000, 1500, 2000],
    'learning_rate': [0.05, 0.1, 0.2],
    'depth': [6, 8, 10],
    'l2_leaf_reg': [1, 3, 5],
    'border_count': [128, 254, 512],
}

# Create a list of all hyperparameter combinations
param_combinations = list(product(*param_grid.values()))

# Initialize variables to track the best result
best_params = None
best_test_r2 = -float('inf')

# Iterate through each hyperparameter combination
for params in param_combinations:
    hyperparameters = dict(zip(param_grid.keys(), params))

    # Create a CatBoostRegressor with the current hyperparameters
    catboost_model = CatBoostRegressor(**hyperparameters, random_state=42, verbose=False)

    # Train the model on the training data
    catboost_model.fit(X_train_scaled, y_train)

    # Predict on the test set
    y_pred_test = catboost_model.predict(X_test_scaled)

    # Calculate the R-squared score on the test set
    test_r2 = r2_score(y_test, y_pred_test)

    # Print the hyperparameters and the corresponding R-squared score
    print("Hyperparameters:", hyperparameters)
    print("Test R-squared:", test_r2)
    print("-" * 50)

    # Check if this is the best result so far
    if test_r2 > best_test_r2:
        best_test_r2 = test_r2
        best_params = hyperparameters

# Print the best hyperparameters and corresponding best test R-squared score
print("Best Hyperparameters:", best_params)
print("Best Test R-squared: ",best_test_r2)
# Out:
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8032802193416699
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.8073517573402792
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8093515963430321
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8048957701982761
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.8040958079975276
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8037829139751043
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8051638151341255
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.8073396229531168
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8084161256641045
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8055219778675071
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.8057546814276847
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8062482384625488
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8052507581014583
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.8061904863971505
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8067650105423514
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8059144721480967
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.8043781308514331
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8064602403942916
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8039206781659808
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.8031133319676493
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8054718367269523
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8044002414227432
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.8049675506298566
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.80559957213724
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8039536764133534
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.805501676182365
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8046651855380387
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8017966793754218
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.8021972231298062
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8064486510672236
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7979981401902982
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.8012028726299236
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8033733031494665
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8030971047865727
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7970853017287373
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8042901169227142
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8003687329444913
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.8017303009459824
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8030239982395457
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8032434993536448
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.8010375678841276
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8006790046426403
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.803992031509869
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.8028572536312923
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8027725299574885
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7964271783051793
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7934956878392257
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7995995384051076
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.795361608792702
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7969430198871197
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7987713146126492
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7979511927330569
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7957002957243157
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.800489223109899
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7975458396189289
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7909722196150458
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7973064144664153
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7979835952065346
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7940124448890855
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7995176128052465
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7974998810094328
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.8009020895221483
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.800329703355662
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.788888216905899
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7944178072733634
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7900183933705812
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7932223185002815
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.79726567896547
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7947669000687558
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7950814337703084
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7935112932763625
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7952809265086399
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.78829648238759
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7778654891254595
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7867332802728466
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.786997631044131
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7863544215476008
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.791325545415644
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7900221754163266
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7911320088717163
# --------------------------------------------------
# Hyperparameters: {'iterations': 1000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7911029292113098
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.802240990791081
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.8065732032134934
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8083142874776688
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8028979181307179
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.80082861999948
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8029700082751448
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8040139519607811
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.8028534942195684
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8085096493907489
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8041310562353008
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.8044142732445533
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.804601609995768
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8051926564064069
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.8048469360762136
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8058220239141098
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8049053702077019
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.8036169242455636
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8055978546076141
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8022485067243568
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.8013519533140689
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8035106341755456
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8023672577043992
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.8034268178461713
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8039632237036296
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8023076571573031
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.8037641838491147
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8030244420614387
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8002228575618436
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.80164456734722
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8038064366841527
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7962375910864286
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7979568461068369
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8020258219680722
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8004611563110586
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7958365464228905
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8027561208465581
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7975904298982095
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7988186295647871
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.800823064471147
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8000665970257804
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7988433353910072
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7986799232228129
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8014218796580003
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.8006697692647813
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8008026139482067
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.793379176593886
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7902182045392564
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7972083557259804
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7925376541753824
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7936020455220619
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7963292724458857
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7955147079143305
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7932679106819943
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7980072266475642
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7946376588324016
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7871469319377932
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7931661430066083
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7938744026529374
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7906938070404785
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7973094635203727
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7932689541078968
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7981186302177274
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7966065385450298
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7852445806225183
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7902806607082122
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7855196372966223
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7903709809612641
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7929841351115453
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.791760850092398
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7907594555936889
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7896136614627162
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7920265703486142
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7838129632178648
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7725793770767014
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7826449891732747
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.781929402074221
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7819145828303071
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.787950241299489
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.785812438602854
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7864629582505112
# --------------------------------------------------
# Hyperparameters: {'iterations': 1500, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7877248461136994
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8011295298503343
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.8061653934241705
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8075976056011209
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8018150390674195
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7998171953616569
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8022115941932227
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8011806875581513
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.8016671684523757
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8076535353502645
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8029285489520361
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.8028015384721935
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8035001743019672
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8037850225089296
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.8037456277582831
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8046709185615009
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8036983853000246
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.802231329551754
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.804758867429207
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.8007269114847528
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7998313615303914
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.8017712207278007
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.8011875593681972
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.8019570781656116
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8025003414875524
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.8007605366941963
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.8024122570091283
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.05, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8015070964215657
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7977621027631772
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7995901669778254
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.802328909332046
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7941418729309702
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.796571432992591
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.8006144244276344
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.798324381600117
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.794700730246982
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.8013654242108653
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7951853144659871
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.796486757637991
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7989452486877295
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7973941209999189
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7970281714350265
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7968973841800941
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7994150369459998
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7980110024873223
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7986313103870872
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7908672007914019
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7877588370940931
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7952313051900668
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7902182297125337
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7914759618582444
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7944447488712675
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7937243720491065
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7906919604007454
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.1, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7960513509124886
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7923966318831759
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7843188650309606
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7908589225467553
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7920684018986888
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7880564934208878
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7946786994297768
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7907904903229744
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.795387944798319
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 6, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7938169000397775
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7817888985134257
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7872158705454095
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7831215335921948
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7863621316047069
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7901991834891957
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7887652802619718
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7874812045909724
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7865602458147942
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 8, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7889396463990168
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 128}
# Test R-squared: 0.7811408385002229
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 254}
# Test R-squared: 0.7701561855146674
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 1, 'border_count': 512}
# Test R-squared: 0.7794816777791826
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 128}
# Test R-squared: 0.7782038645700483
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 254}
# Test R-squared: 0.7782339472674659
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 3, 'border_count': 512}
# Test R-squared: 0.7854623495509271
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 128}
# Test R-squared: 0.7824146873936482
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 254}
# Test R-squared: 0.7837760895351176
# --------------------------------------------------
# Hyperparameters: {'iterations': 2000, 'learning_rate': 0.2, 'depth': 10, 'l2_leaf_reg': 5, 'border_count': 512}
# Test R-squared: 0.7845816807360936
# --------------------------------------------------
# Best Hyperparameters: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 6, 'l2_leaf_reg': 1, 'border_count': 512}
# Best Test R-squared:  0.8093515963430321

# %%
from catboost import CatBoostRegressor

# Create and train a CatBoostRegressor
model = CatBoostRegressor(iterations=1000, learning_rate=0.05, depth=6, l2_leaf_reg=1, border_count=512, random_state=42)
model.fit(X_train_scaled, y_train, verbose=100)
y_train_pred = model.predict(X_train_scaled)
train_r2 = r2_score(y_train, y_train_pred)

# Predict on the test set
y_pred = model.predict(X_test_scaled)

# Evaluate the model
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the predicted values and R^2 score
print('Train R2 Score:', train_r2)
print('Test R2 Score:', r2)
# Out:
# 0:	learn: 7.5579811	total: 7.89ms	remaining: 7.88s
# 100:	learn: 3.5362562	total: 769ms	remaining: 6.84s
# 200:	learn: 3.4507468	total: 1.51s	remaining: 6.02s
# 300:	learn: 3.3954300	total: 2.26s	remaining: 5.24s
# 400:	learn: 3.3472834	total: 3s	remaining: 4.48s
# 500:	learn: 3.3041264	total: 3.74s	remaining: 3.73s
# 600:	learn: 3.2681210	total: 4.48s	remaining: 2.97s
# 700:	learn: 3.2335351	total: 5.21s	remaining: 2.22s
# 800:	learn: 3.2042492	total: 5.96s	remaining: 1.48s
# 900:	learn: 3.1832036	total: 6.7s	remaining: 736ms
# 999:	learn: 3.1600412	total: 7.43s	remaining: 0us
# Train R2 Score: 0.8377197692229563
# Test R2 Score: 0.8093515963430321

# %%
from sklearn.ensemble import GradientBoostingRegressor
# Create and train the Gradient Boosting Regression model
model = GradientBoostingRegressor(random_state=42)
model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_scaled)

# Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r_squared)
# Out:
# Mean Squared Error: 12.944332593588381
# R-squared: 0.8009170571967889

# %%
# Define the hyperparameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 3, 4],
    'min_samples_leaf': [1, 2, 3],
    'subsample': [0.8, 0.9, 1.0],
}

# Create a list of all hyperparameter combinations
param_combinations = list(product(*param_grid.values()))

# Initialize variables to track the best result
best_params = None
best_test_r2 = -float('inf')

# Iterate through each hyperparameter combination
for params in param_combinations:
    hyperparameters = dict(zip(param_grid.keys(), params))

    # Create a GradientBoostingRegressor with the current hyperparameters
    gb_model = GradientBoostingRegressor(**hyperparameters, random_state=42)

    # Train the model on the training data
    gb_model.fit(X_train_scaled, y_train)

    # Predict on the test set
    y_pred_test = gb_model.predict(X_test_scaled)

    # Calculate the R-squared score on the test set
    test_r2 = r2_score(y_test, y_pred_test)

    # Print the hyperparameters and the corresponding R-squared score
    print("Hyperparameters:", hyperparameters)
    print(f"Test R-squared:", test_r2)
    print("-" * 50)

    # Check if this is the best result so far  
    if test_r2 > best_test_r2:
        best_test_r2 = test_r2
        best_params = hyperparameters

# Print the best hyperparameters and corresponding best     test R-squared score
print("Best Hyperparameters:", best_params)
print("Best Test R-squared:", best_test_r2)
# Out:
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.6857348572176716
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.6856445044098605
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.6864344455097945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.6857348572176716
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.6856445044098605
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.6864344455097945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.685665251334222
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.6857180061955733
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.6864344455097945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.6857348572176716
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.6856445044098605
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.6864344455097945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.6857348572176716
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.6856445044098605
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.6864344455097945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.685665251334222
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.6857180061955733
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.6864344455097945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.6857348572176716
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.6856445044098605
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.6864344455097945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.6857348572176716
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.6856445044098605
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.6864344455097945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.685665251334222
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.6857180061955733
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.6864344455097945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.687623398550034
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.6880818426189426
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.6880151284837585
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.6876225221656274
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.6880818426189426
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.6880151284837585
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.6878326093590815
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.6881595765989406
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.6880151284837585
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.687623398550034
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.6880818426189426
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.6880151284837585
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.6876225221656274
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.6880818426189426
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.6880151284837585
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.6878326093590815
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.6881595765989406
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.6880151284837585
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.687623398550034
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.6880818426189426
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.6880151284837585
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.6876225221656274
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.6880818426189426
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.6880151284837585
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.6878326093590815
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.6881595765989406
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.6880151284837585
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.6902875186852446
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.6902683647658832
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.6903476265322215
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.6904800677944445
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.6903992247906564
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.6902307355095646
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.6904429435018442
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.6902115295503568
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.6901846620526442
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.6904988904164343
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.6902406503515517
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.6903476265322215
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.6904800677944445
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.6903992247906564
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.6902307355095646
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.6904429435018442
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.6902115295503568
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.6901846620526442
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.690484984874071
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.6904021846875448
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.6903476265322215
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.6904800677944445
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.6903992247906564
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.6902307355095646
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.6904429435018442
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.6902115295503568
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.6901846620526442
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8001577281904402
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8007766381201593
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8009170571967889
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.7997218475777236
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8006872461529575
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8006584890553349
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8005022452039783
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8015944426290686
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8002009145106069
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8008756681452525
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.800553914102907
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8005782704620783
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.7997218475777236
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8006872461529575
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8006584890553349
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8005022452039783
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8015944426290686
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8002009145106069
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8002970810396722
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8001153742946836
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8013966553737114
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.7997218475777236
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8006872461529575
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8006584890553349
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8005022452039783
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8015944426290686
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8002009145106069
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8035168915181794
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8038862164004051
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8038356922523122
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8034945303181945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8045296963931337
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8039199093947076
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.803135206525126
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.80349156524765
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8022559365580697
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8032795605792985
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8047373672432858
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8033227857040023
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8034945303181945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8045296963931337
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8039199093947076
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.803135206525126
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.80349156524765
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8022559365580697
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8037301328793355
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8044883536873983
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.803516656951537
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8034945303181945
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8045296963931337
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8039199093947076
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.803135206525126
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.80349156524765
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8022559365580697
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8061269852192214
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8050238760401235
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.80571291241282
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8053342911757495
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8063198110780748
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.80653613471017
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8061365099484517
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8061715061937218
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8058678565196074
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8060332518965162
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8067793793983409
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8059545428778414
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8053342911757495
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8063198110780748
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.80653613471017
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8061365099484517
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8061715061937218
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8058678565196074
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8059302401647817
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8074623326103523
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8052587384781931
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8053342911757495
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8063198110780748
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.80653613471017
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8061365099484517
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8061715061937218
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8058678565196074
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8009110565659293
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8047621322270443
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.801791025607622
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8052474253569069
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.804966527322853
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8029662685860841
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8042978355825061
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8041598215814775
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8038166990706288
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.803000557103321
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8053856636627346
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8021325183840814
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8052474253569069
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.804966527322853
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8029662685860841
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8042978355825061
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8041598215814775
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8038166990706288
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8006295241256073
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8044293559596316
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8033599927521828
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8052474253569069
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.804966527322853
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8029662685860841
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8042978355825061
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8041598215814775
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8038166990706288
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8066948929570411
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8051578910244026
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8057443083576123
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8059276284108344
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8041850381294899
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8059789946588757
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8064890214508049
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8055265232312036
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8062756661352763
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8059594268050447
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8083872679493096
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8060953957390352
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8059276284108344
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8041850381294899
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8059789946588757
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8064890214508049
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8055265232312036
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8062756661352763
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8077832806868275
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8030900142282867
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8059880818200014
# --------------------------------------------------
# ...
# Test R-squared: 0.8034742367559546
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.806828576418553
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8059939493336379
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8048787674433822
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.806612269553517
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8061961176766423
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8064782490698841
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8022442372439564
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8069954311090317
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8064902978803457
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.806828576418553
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8059939493336379
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.8048787674433822
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.806612269553517
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.8061961176766423
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8064782490698841
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8037815052853887
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8058965757085154
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8044802884860043
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8015059259870083
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8050623217814561
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.807337079826053
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8039809077851823
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.805312713098759
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8058150501048922
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8010002440689478
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8049139605842518
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8068198368327334
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8015059259870083
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8050623217814561
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.807337079826053
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8039809077851823
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.805312713098759
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8058150501048922
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.8055461824295692
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8005860491906005
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8051139629797811
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.8015059259870083
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.8050623217814561
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.807337079826053
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.8039809077851823
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.805312713098759
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8058150501048922
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.7789380987744157
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.7901045348727049
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.7989615431271068
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.7913163367971476
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.7981934682668791
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.7971458573638327
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.7973259124788414
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.797467265227257
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8027845053925186
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.7978736699896294
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.7984988005855642
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.798119437872515
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.7913163367971476
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.7981934682668791
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.7971458573638327
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.7973259124788414
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.797467265227257
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8027845053925186
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8}
# Test R-squared: 0.7904070038025096
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9}
# Test R-squared: 0.8001796519953811
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 1.0}
# Test R-squared: 0.8005020572007557
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.8}
# Test R-squared: 0.7913163367971476
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9}
# Test R-squared: 0.7981934682668791
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 1.0}
# Test R-squared: 0.7971458573638327
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.8}
# Test R-squared: 0.7973259124788414
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.9}
# Test R-squared: 0.797467265227257
# --------------------------------------------------
# Hyperparameters: {'n_estimators': 300, 'learning_rate': 0.2, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 1.0}
# Test R-squared: 0.8027845053925186
# --------------------------------------------------
# Best Hyperparameters: {'n_estimators': 100, 'learning_rate': 0.2, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.9}
# Best Test R-squared: 0.8083872679493096

# %%
from sklearn.ensemble import GradientBoostingRegressor
# Create and train the Gradient Boosting Regression model
model = GradientBoostingRegressor(n_estimators=100, learning_rate= 0.2, max_depth= 4, min_samples_split= 3, min_samples_leaf= 1, subsample= 0.9, random_state=42)
model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_scaled)

# Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r_squared)
# Out:
# Mean Squared Error: 12.4586210044222
# R-squared: 0.8083872679493096
